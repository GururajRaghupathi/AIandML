# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from scipy import misc

# %%
#Importing the other necessary libraries
import os
import pathlib
import glob
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
import imageio
cat_im = imageio.imread('cat_orig.png')
dog_im = imageio.imread('dog_orig.png')
print("Cat image shape :",cat_im.shape)
print("Dog image shape :",dog_im.shape)
# Out:
# Cat image shape : (128, 128, 3)
# Dog image shape : (128, 128, 3)

# %%
#To see the structure of the image let's display one row of the image matrix
#print('The first row of the image matrix contains',len(cat_im[1]),'pixels')
print(cat_im[0][0])
plt.imshow(dog_im)
# Out:
# [159 162 171]

# %%
import cv2
#To transfrom the colorspace from BGR to grayscale so as to make things simpler
grayCatImg = cv2.cvtColor(cat_im,cv2.COLOR_BGR2GRAY)
grayDogImg = cv2.cvtColor(dog_im,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(grayDogImg)
grayDogImg.shape
#print(grayCatImg[0])
#print(grayDogImg[0])
# Out:
# (128, 128)

# %%
#convert data value to be between 0 and 1
np.array(grayCatImg)
np.array(grayDogImg)
grayCatImg_Convetred = np.divide(grayCatImg,255)
grayCatImg_Convetred = np.divide(grayDogImg,255)
print(grayCatImg_Convetred.shape)
print(grayCatImg_Convetred.shape)
# Out:
# (128, 128)
# (128, 128)
